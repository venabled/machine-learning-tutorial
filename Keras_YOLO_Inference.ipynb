# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/venabled/machine-learning-tutorial/blob/master/Keras_YOLO_Inference.ipynb)

# %%
import keras
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !wget https://github.com/qqwweee/keras-yolo3/archive/master.zip
# Out:
# Redirecting output to ‘wget-log.3’.
#
# Redirecting output to ‘wget-log.4’.

# %%
# !unzip master.zip
# Out:
# Archive:  master.zip
# e6598d13c703029b2686bc2eb8d5c09badf42992
# replace keras-yolo3-master/.gitignore? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: keras-yolo3-master/.gitignore
#   inflating: keras-yolo3-master/LICENSE
#   inflating: keras-yolo3-master/README.md
#   inflating: keras-yolo3-master/coco_annotation.py
#   inflating: keras-yolo3-master/convert.py
#   inflating: keras-yolo3-master/darknet53.cfg
#   inflating: keras-yolo3-master/font/FiraMono-Medium.otf
#   inflating: keras-yolo3-master/font/SIL Open Font License.txt
#   inflating: keras-yolo3-master/kmeans.py
#   inflating: keras-yolo3-master/model_data/coco_classes.txt
#   inflating: keras-yolo3-master/model_data/tiny_yolo_anchors.txt
#   inflating: keras-yolo3-master/model_data/voc_classes.txt
#   inflating: keras-yolo3-master/model_data/yolo_anchors.txt
#   inflating: keras-yolo3-master/train.py
#   inflating: keras-yolo3-master/train_bottleneck.py
#   inflating: keras-yolo3-master/voc_annotation.py
# ...

# %%
# !python ./keras-yolo3-master/convert.py ./keras-yolo3-master/yolov3.cfg ./yolov3.weights ./keras-yolo3-master/model_data/yolo.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# ...

# %%
cd ./keras-yolo3-master/
# Out:
# /content/keras-yolo3-master

# %%
import yolo
yv3 = yolo.YOLO()
# Out:
# model_data/yolo.h5 model, anchors, and classes loaded.

# %%
# !wget https://i.imgur.com/ytjRi7W.png
# Out:
# Redirecting output to ‘wget-log.4’.

# %%
cat_img = cv2.imread('./ytjRi7W.png', cv2.IMREAD_COLOR)[:, :, [2, 1, 0]]
plt.imshow(cat_img)
plt.grid(False)

# %%
cat_PIL = Image.open('./ytjRi7W.png')
out_img = yv3.detect_image(cat_PIL)
out_img
# Out:
# (416, 416, 3)
# Found 1 boxes for img
# cat 1.00 (65, 33) (224, 224)
# 4.802076570998906
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=224x224 at 0x7F1E41D68588>

# %%
# !wget https://i2.wp.com/www.mfortyfive.com/wp-content/uploads/2018/07/unspecified-2-3.jpg
# Out:
# Redirecting output to ‘wget-log.5’.

# %%
ls
# Out:
# coco_annotation.py                unspecified-2-3.jpg?resize=1024%2C640
# convert.py                        voc_annotation.py
# darknet53.cfg                     wget-log
# font/                             wget-log.1
# hih-ki0D--621x414@LiveMint.jpg    wget-log.2
# hih-ki0D--621x414@LiveMint.jpg.1  wget-log.3
# kmeans.py                         wget-log.4
# LICENSE                           wget-log.5
# model_data/                       yolo3/
# __pycache__/                      yolo.py
# README.md                         yolov3.cfg
# train_bottleneck.py               yolov3-tiny.cfg
# train.py                          yolo_video.py
# unspecified-2-3.jpg               ytjRi7W.png
# unspecified-2-3.jpg.1             ytjRi7W.png.1

# %%
yv3.detect_image(Image.open('./unspecified-2-3.jpg'))
# Out:
# (416, 416, 3)
# Found 22 boxes for img
# umbrella 0.33 (675, 283) (737, 305)
# umbrella 0.39 (1011, 268) (1127, 304)
# umbrella 0.53 (1160, 273) (1274, 311)
# car 0.32 (1086, 322) (1157, 351)
# car 0.93 (430, 329) (700, 446)
# car 0.99 (524, 325) (905, 511)
# car 1.00 (649, 360) (1277, 623)
# person 0.31 (547, 308) (563, 332)
# person 0.37 (0, 262) (1280, 376)
# person 0.45 (84, 312) (101, 352)
# person 0.47 (28, 313) (45, 363)
# person 0.49 (1254, 312) (1278, 411)
# person 0.58 (1039, 310) (1090, 351)
# person 0.59 (939, 308) (972, 353)
# person 0.65 (881, 312) (916, 360)
# person 0.73 (0, 311) (32, 397)
# person 0.75 (1201, 312) (1231, 366)
# person 0.90 (47, 308) (67, 366)
# person 0.95 (107, 315) (148, 402)
# person 0.98 (157, 313) (196, 396)
# person 0.99 (318, 309) (483, 800)
# person 1.00 (249, 286) (362, 789)
# 2.4930568039999343
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x800 at 0x7F1E41DEBB70>

# %%
# !wget https://www.livemint.com/rf/Image-621x414/LiveMint/Period2/2017/07/19/Photos/Processed/hih-ki0D--621x414@LiveMint.jpg
# Out:
# Redirecting output to ‘wget-log.6’.

# %%
yv3.detect_image(Image.open('./hih-ki0D--621x414@LiveMint.jpg'))
# Out:
# (416, 416, 3)
# Found 25 boxes for img
# truck 0.84 (320, 214) (365, 257)
# motorbike 0.32 (123, 245) (135, 262)
# motorbike 0.38 (204, 232) (217, 256)
# motorbike 0.40 (187, 234) (205, 259)
# motorbike 0.44 (85, 236) (102, 258)
# motorbike 0.44 (119, 234) (136, 258)
# motorbike 0.52 (141, 233) (158, 256)
# motorbike 0.54 (86, 246) (101, 263)
# motorbike 0.59 (189, 244) (202, 264)
# motorbike 0.67 (107, 235) (123, 255)
# motorbike 0.92 (162, 246) (179, 271)
# motorbike 0.97 (45, 291) (104, 392)
# car 0.33 (418, 240) (475, 257)
# car 0.89 (377, 228) (429, 279)
# car 0.92 (278, 225) (327, 274)
# car 0.93 (232, 223) (259, 258)
# car 0.97 (249, 227) (288, 266)
# car 0.98 (583, 253) (621, 381)
# car 0.99 (493, 236) (616, 336)
# car 0.99 (384, 247) (497, 347)
# person 0.38 (119, 234) (136, 258)
# person 0.46 (165, 225) (180, 245)
# person 0.50 (85, 236) (102, 258)
# person 0.70 (161, 226) (182, 262)
# person 0.85 (36, 253) (100, 317)
# 2.4688693989992316
# ...

# %%
yv3.yolo_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           leaky_re_lu_1[0][0]
# ...
